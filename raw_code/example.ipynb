# %% [markdown]
# # Chicago Food Inspections Data Pipeline
#
# This notebook contains a complete data pipeline for processing, cleaning, analyzing, and storing Chicago Food Inspections data. The pipeline consists of several steps:
#
# ## Data Loading and Pre-processing
# - Imports custom functions from the `data_preparation` module
# - Loads food inspection data from CSV format
# - Transforms column names for consistency
# - Cleans and standardizes data fields:
#     - License numbers
#     - ZIP codes
#     - Geographic information (city/state)
#     - Missing coordinates (geocoding)
#     - Risk categories
#     - Business names
# - Saves cleaned dataset to CSV for future use
#
# ## Data Profiling and Quality Checks
# The pipeline performs various data quality checks:
# - Profile business names for consistency
# - Analyze risk levels distribution
# - Validate inspection dates
# - Examine inspection types
# - Review inspection results
# - Verify location data (ZIP codes, states)
# - Check for proper mapping between ZIP/state/city
# - Inspect violation data structure and content
#
# ## Database Normalization and Storage
# The data is normalized into three main tables:
# 1. **Facility** - Information about food establishments
# 2. **Inspection** - Details about each inspection
# 3. **Violations** - Individual violations found during inspections
#
# These tables are then stored in a SQLite database called `food_inspections.db`
#
# ## How to Run
# 1. Ensure you have the required dependencies installed (`pandas`, etc.)
# 2. Place the input CSV file (`Food_Inspections_20250216.csv`) in the working directory
# 3. Make sure the `data_preparation.py` module is available in your path
# 4. Execute the notebook cells in order
# 5. Review the profiling results to understand data quality
# 6. Access the normalized data in the SQLite database
#
# The final database structure follows a star schema design that allows for efficient querying across inspection records, facilities, and violations.

# %%
from data_preparation import *

# %% [markdown]
# # Loading and preprocessing the data

# %%
food_dataset = pd.read_csv("Food_Inspections_20250216.csv",  dtype={'License #': str, 'Zip': str})
updated_food_dataset = food_dataset.copy()
updated_food_dataset = col_name_changer(updated_food_dataset)
updated_food_dataset = process_license_numbers(updated_food_dataset)
updated_food_dataset = clean_zip_data(updated_food_dataset).drop(columns=['zip','zip_valid'],axis=1).rename(columns={'zip_clean':'zip'})
updated_food_dataset['state'] = updated_food_dataset.apply(
    lambda row: row['state'] if pd.notna(row['state']) else get_zip_info(row['zip'],'state'),
    axis=1)
updated_food_dataset['city'] = updated_food_dataset.apply(
    lambda row: row['city'] if pd.notna(row['city']) else get_zip_info(row['zip'],'city'),
    axis=1)
updated_food_dataset = geocode_missing_coordinates(updated_food_dataset)
updated_food_dataset = risk_column_transformation(updated_food_dataset)
updated_food_dataset = standardize_name_columns(updated_food_dataset)
updated_food_dataset['aka_name'] = updated_food_dataset['aka_name'].fillna(updated_food_dataset['dba_name'])
updated_food_dataset = fix_city_name(updated_food_dataset)
updated_food_dataset.to_csv("cleaned_dataset_for_FD.csv", index=False)

# %% [markdown]
# # Profiling and data quality check

# %%
# General profiling
separated_stats = generate_descriptive_stats(updated_food_dataset, separate_tables=True)

# Print numerical table
print("\n🔢 NUMERICAL VARIABLES")
print(separated_stats['numerical'].to_markdown(tablefmt="grid", stralign="center", numalign="center", floatfmt=".2f"))

# Print categorical table
print("\n📝 CATEGORICAL VARIABLES")
print(separated_stats['categorical'].to_markdown(tablefmt="grid", stralign="left"))

# Print datetime table
print("\n DATETIME VARIABLES")
print(separated_stats['datetime'].to_markdown(tablefmt="grid", stralign="left"))
# Out:
# 🔢 NUMERICAL VARIABLES
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /opt/miniconda3/lib/python3.12/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File /opt/miniconda3/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'tabulate'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 6
#       4 # Print numerical table
#       5 print("\n🔢 NUMERICAL VARIABLES")
# ----> 6 print(separated_stats['numerical'].to_markdown(tablefmt="grid", stralign="center", numalign="center", floatfmt=".2f"))
#       8 # Print categorical table
#       9 print("\n📝 CATEGORICAL VARIABLES")
#
# File /opt/miniconda3/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File /opt/miniconda3/lib/python3.12/site-packages/pandas/core/frame.py:2983, in DataFrame.to_markdown(self, buf, mode, index, storage_options, **kwargs)
#    2981 kwargs.setdefault("tablefmt", "pipe")
#    2982 kwargs.setdefault("showindex", index)
# -> 2983 tabulate = import_optional_dependency("tabulate")
#    2984 result = tabulate.tabulate(self, **kwargs)
#    2985 if buf is None:
#
# File /opt/miniconda3/lib/python3.12/site-packages/pandas/compat/_optional.py:138, in import_optional_dependency(name, extra, errors, min_version)
#     136 except ImportError:
#     137     if errors == "raise":
# --> 138         raise ImportError(msg)
#     139     return None
#     141 # Handle submodules: if we have submodule, grab parent module from sys.modules
#
# ImportError: Missing optional dependency 'tabulate'.  Use pip or conda to install tabulate.

# %%
profile_name(updated_food_dataset)
# Out:
# Name Similarity Statistics
# ========================================
#                                           Description    Value
# missing_initial       Initial missing aka_name values        0
# missing_filled   aka_name values filled with dba_name        0
# exact_matches             Exact matches between names  211,890
# similar_count         Similar names (above threshold)  238,958
# avg_similarity               Average similarity score     0.90
# ========================================
# (        inspection_id                            dba_name  \
#  0             1106427                blooming bud daycare
#  1             2608378                         babas halal
#  2             1106406            first zabiha meat bazaar
#  3             2609909                        happy market
#  4             2609927          sat kaival food inc/subway
#  ...               ...                                 ...
#  287232        2610937            dapper's east restaurant
#  287233        2610845                           sharpie's
#  287234        2610409            ace sushi @potash market
#  287235        2610823                kitchen chicago, llc
#  287236        2610068  hannah's bretzel 227 w. monroe llc
#
#                            aka_name license_num       facility_type    risk  \
#  0             blooming bud daycare     2215789  Daycare Combo 1586    High
#  1                      babas halal     2684170          Restaurant    High
#  2         first zabiha meat bazaar     2232559       Grocery Store  Medium
#  3                     happy market     2912802       Grocery Store  Medium
#  4       sat kaival food inc/subway     2728400          Restaurant    High
#  ...                            ...         ...                 ...     ...
#  287232    dapper's east restaurant       12540          Restaurant    High
#  287233                   sharpie's     3002203          Restaurant     Low
#  287234                   ace sushi     2808766          Restaurant    High
#  287235        kitchen chicago, llc     2119905      Shared Kitchen    High
#  287236            hannah's bretzel     2428372          Restaurant    High
#
#                       address     city state inspection_date  \
#  0         5715 N LINCOLN AVE  CHICAGO    IL      03/07/2013
#  1           7901 S DAMEN AVE  CHICAGO    IL      12/03/2024
#  2           2907 W DEVON AVE  CHICAGO    IL      02/20/2013
#  3       2334 S WENTWORTH AVE  CHICAGO    IL      01/02/2025
#  4            1916 S STATE ST  CHICAGO    IL      01/02/2025
#  ...                      ...      ...   ...             ...
#  287232     2901 W ADDISON ST  CHICAGO    IL      01/23/2025
#  287233     1721 N ELSTON AVE  CHICAGO    IL      01/22/2025
#  287234        875 N STATE ST  CHICAGO    IL      01/13/2025
#  287235      324 N LEAVITT ST  CHICAGO    IL      01/22/2025
#  287236       227 W MONROE ST  CHICAGO    IL      01/06/2025
#
#                  inspection_type             results  \
#  0                       License                Pass
#  1                     Complaint                Fail
#  2                       License                Fail
#  3                       Canvass  Pass w/ Conditions
#  4                       Canvass                Pass
#  ...                         ...                 ...
#  287232  Complaint Re-Inspection                Pass
#  287233                  License           Not Ready
#  287234                  Canvass                Pass
#  287235                  Canvass                Pass
#  287236                  Canvass                Pass
#
#                                                 violations   latitude  \
#  0       32. FOOD AND NON-FOOD CONTACT SURFACES PROPERL...  41.985390
#  1       1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...  41.750189
#  2       11. ADEQUATE NUMBER, CONVENIENT, ACCESSIBLE, D...  41.997401
#  3       2. CITY OF CHICAGO FOOD SERVICE SANITATION CER...  41.849954
#  4       36. THERMOMETERS PROVIDED & ACCURATE - Comment...  41.856053
#  ...                                                   ...        ...
#  287232  47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE...  41.946553
#  287233                                                NaN  41.913729
#  287234  55. PHYSICAL FACILITIES INSTALLED, MAINTAINED ...  41.898878
#  287235  49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Com...  41.887434
#  287236  37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER ...  41.880539
#
#          longitude                                  location    zip  \
#  0      -87.698734   (41.98538950526786, -87.69873407149943)  60659
#  1      -87.672986  (41.750189342293375, -87.67298583977204)  60620
#  2      -87.702385   (41.99740137039031, -87.70238538227812)  60659
#  3      -87.632094   (41.84995400192252, -87.63209419559098)  60616
#  4      -87.627311   (41.85605269621059, -87.62731125804903)  60616
#  ...           ...                                       ...    ...
#  287232 -87.700536     (41.94655282616904, -87.700535765616)  60618
#  287233 -87.664223   (41.91372879440366, -87.66422290709808)  60642
#  287234 -87.628111    (41.89887819742381, -87.6281111483033)  60610
#  287235 -87.681849   (41.88743405025222, -87.68184949426895)  60612
#  287236 -87.634592   (41.88053924995021, -87.63459246351388)  60606
#
#          name_similarity name_relationship
#  0              1.000000           similar
#  1              1.000000           similar
#  2              1.000000           similar
#  3              1.000000           similar
#  4              1.000000           similar
#  ...                 ...               ...
#  287232         1.000000           similar
#  287233         1.000000           similar
#  287234         0.545455   some_similarity
#  287235         1.000000           similar
#  287236         0.640000   some_similarity
#
#  [287237 rows x 19 columns],
#  {'missing_initial': 0,
#   'missing_filled': 0,
#   'exact_matches': 211890,
#   'similar_count': 238958,
#   'avg_similarity': 0.9034951463410731})

# %%
profile_risk_column(updated_food_dataset)
# Out:
# {'value_counts':          Count  Percentage
#  risk
#  High    211761       73.72
#  Medium   52347       18.22
#  Low      22973        8.00
#  All        156        0.05,
#  'invalid_values': array([], dtype=object),
#  'pre_missing_count': 0,
#  'invalid_count': 0}

# %%
profile_inspection_date(updated_food_dataset)
# Out:
# Date Range: 2010-01-04 to 2025-02-14
# Most Active Year: 2016 (22,818 inspections)
# Most Active Month: October (26,556 inspections)

# %%
profile_inspection_type(updated_food_dataset)
# Out:
# Standardized Inspection Type Distribution:
# =======================================================
# • Canvass                       : 149,450 (52.0%)
# • License                       :  38,809 (13.5%)
# • Complaint                     :  35,873 (12.5%)
# • Canvass (Re-Inspection)       :  31,876 (11.1%)
# • License (Re-Inspection)       :  12,006 (4.2%)
# • Complaint (Re-Inspection)     :  11,332 (3.9%)
# • Other                         :   5,660 (2.0%)
# • Suspect Food Poisoning        :     977 (0.3%)
# • Consultation                  :     697 (0.2%)
# • Task-Force Inspection         :     337 (0.1%)
# • Suspect Food Poisoning (Re-Inspection):     219 (0.1%)
# =======================================================
# /Users/giangson/coding/-DATA-PREPARATION-FOR-FOOD-INSPECTION/data_preparation.py:287: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %%
profile_results(updated_food_dataset)
# Out:
# Outcome Distribution Summary:
# ========================================
# • Pass                :  148,027 (51.5%)
# • Pass W/ Conditions  :   43,357 (15.1%)
# • Fail                :   55,771 (19.4%)
# • Out Of Business     :   24,078 (8.4%)
# • No Entry            :   12,112 (4.2%)
# • Not Ready           :    3,800 (1.3%)
# • Business Not Located:       92 (0.0%)
# ========================================

# %%
profile_zip(updated_food_dataset)

# %%
profile_state(updated_food_dataset)
# Out:
#   State   Count  Percentage
# 0    IL  287222         1.0
# 1    IN      10         0.0
# 2    CA       2         0.0
# 3    CO       1         0.0
# 4    NY       1         0.0
# 5    WI       1         0.0

# %%
check_zip_state_city_mapping(updated_food_dataset)
# Out:
# ZIPs with conflicting states: 0
# Empty DataFrame
# Columns: [zip, state, city]
# Index: []

# %%
check_city_state_spelling(updated_food_dataset)
# Out:
# Potential duplicates for 'CHICAGO': ['CHICAGO', '312CHICAGO']

# %%
profile_violations(updated_food_dataset, sample_size=1000)
# Out:
# violations Column Structure Analysis:
#
# Total Samples:
#   1000
#
# Avg Length:
#   1841.554
#
# Separator Counts:
#   - |: 1842.554
#   - .: 1841.554
#   - -: 15.922
#   - :: 9.85
#   - ;: 1.581
#
# Violation Counts:
#
# Common Patterns:
#   - 100.0% start with digits followed by period
#   - 100.0% contain 'Comments:' text
#
# Violations Per Entry:
#   - min: 1
#   - max: 28
#   - avg: 7.555
#   - distribution: {6: 98, 7: 96, 9: 93, 8: 83, 5: 83, 4: 78, 10: 78, 1: 74, 12: 58, 11: 53, 3: 52, 2: 44, 13: 27, 14: 22, 15: 21, 16: 14, 17: 10, 19: 8, 18: 3, 22: 2, 28: 1, 23: 1, 21: 1}
# {'total_samples': 1000,
#  'avg_length': 1841.554,
#  'separator_counts': {'|': 1842.554,
#   '.': 1841.554,
#   '-': 15.922,
#   ':': 9.85,
#   ';': 1.581},
#  'violation_counts': [],
#  'common_patterns': ['100.0% start with digits followed by period',
#   "100.0% contain 'Comments:' text"],
#  'sample_entries': ['3. POTENTIALLY HAZARDOUS FOOD MEETS TEMPERATURE REQUIREMENT DURING STORAGE, PREPARATION DISPLAY AND SERVICE - Comments: OBSERVED SAUSAGE PIZZA WITH APPROXIMATE WEIGHT APPROXIMATELY 1LB VALUED AT $5 AT 119.2 F AND CHEESEY BREAD APPROXIMATELY 1 LB VALUED AT $2.50 AT 109.4 F. FOOD DISPOSED OF AND DENATURED. CRITICAL VIOLATION 7
UPPLIED, & CLEANED - Comments: OBSERVED EXCESSIVE WASTE (TOILET PAPER) OVERFLOWING FROM GARBAGE CANS ONTO THE FLOOR IN MEN'S EAST RESTROOM. OBSERVED TOILETS HEAVILY SOILED IN MEN'S RESTROOM EAST, AND WOMEN'S RESTROOM SOUTH. MUST DETAIL CLEAN AND SANITIZE ALL EQUIPMENT AND FLOORS IN RESTROOMS. MUST MAINTAIN SAME.  | 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: OBSERVED EXCESSIVE GREASE AND DUST ON VENTILATION HOOD IN FRONT PREP AREA OVER FRYERS. MUST DETAIL CLEAN AND SANITIZE. MUST MAINTAIN SAME.  | 58. ALLERGEN TRAINING AS REQUIRED - Comments: NO PROOF OF ALLERGEN TRAINING ON SITE. MUST PROVIDE. NO CITATION ISSUED.",
#   '3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: FOUND NO EMPLOYEE HEALTH POLICY ON SITE. INSTRUCTED TO IMPLEMENT A POLICY WHERE ALL FOOD/CONDITIONAL EMPLOYEES ACKOWLEDGES THEIR RESPONSIBILITIES IN REPORTING ANY ILLNESS INCURRED THAT IS TRANSMISSIBLE THROUGH FOOD. PRIORITY FOUNDATION VIOLATION 7-38-010 NO CITATION ISSUED | 5. PROCEDURES FOR RESPONDING TO VOMITING AND DIARRHEAL EVENTS - Comments: FOUND NO PROCEDURES FOR RESPONDING TO VOMITING AND DIARRHEAL EVENTS NOR A CLEAN UP KIT ON SITE. INSTRUCTED TO IMPLEMENT A PROCEDURE AND PROVIDE ALL NECESSARY SUPPLIES FOR HANDLING THESE EVENTS. PRIORITY FOUNDATION VIOLATION 7-38-005 NO CITATTION ISSUED. | 23. PROPER DATE MARKING AND DISPOSITION - Comments: FOUND TCS FOODS (CHICKEN, FISH, ETC.) THAT HAVE BEEN PREPARED OR REMOVED FROM ITS ORIGINAL PACKAGING STORED INSIDE THE WALK IN COOLER AND NOT PROPERLY LABELED OR DATED. INSTRUCTED TO DATE/LABEL ALL TCS FOODS THAT HAVE BEEN REMOVED FROM ITS ORIGINAL PACKAGING OR PREPARED AND HELD FOR MORE THAN 24 HOURS. PRIORITY FOUNDATION VIOLATION 7-38-005 NO CITATION ISSUED | 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: FOUND THE CAN OPENER WITH DIRT AND FOOD BUILD UP. INSTRUCTED TO DETAIL CLEAN AND MAINTAIN. | 49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: FOUND THE FOLLOWING WITH FOOD, DIRT AND GREASE BUILD UP:  -INTERIOR/EXTERIOR OF THE DEEP FRYERS. -THE STORAGE RACKS AND RUBBER GASKETS INSIDE THE WALK IN/REACH IN COOLERS AND STORAGE AREAS. -KNIFE RACK -LARGE PLASTIC CONTAINERS USED TO STORE TCS FOODS INSIDE THE WALK IN/REACH IN COOLERS  -LARGE GARBAGE CANS USED TO STORE BULK INGREDIENTS.  INSTRUCTED TO DETAIL CLEAN ALL TO REMOVE THE THICK BUILD UP OF DIRT, FOOD AND GREASE. MAINTAIN SAME. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: FOUND THE INTERIOR OF THE FLOOR DRAINS AND FLOORS WITH ACCUMILATED GREASE, FOOD AND DIRT BUILD UP IN THE CORNERS, UNDER THE COOKING/COOLING EQUIPMENT, INSIDE THE WALK IN COOLER/FREEZER AND UNDER/AROUND ALL SINKS AND STORAGE RACKS.  -FOUND THE WALLS AND CEILING WITH DIRT, DUST AND FOOD SPILLS IN THE STORAGE AND FOOD PREPARATION AREAS, AROUND THE SINKS AND STORAGE RACKS.  INSTRUCTED TO DETAIL CLEAN AND MAINTAIN THE FLOOR DRAINS, FLOORS, WALLS AND CEILING THROUGH OUT. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: THERE IS A HOLE IN THE WALL ACROSS FROM THE TOILET ROOM. INSTRUCTED TO REPAIR WALL.  -BROKEN/DAMAGED FLOOR TILES IN THE FRONT FOOD PREPARATION AREA. INSTRUCTED TO REPLACE ALL BROKEN/DAMAGED FLOOR TILES THROUGH OUT AS NEEDED. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: MOPS NOT PROPERLY STORED WHEN NOT IN USE. INSTRUCTED TO STORE HANGING UP FOR PROPER DRYING WHEN NOT IN USE.',
#   '53. TOILET FACILITIES: PROPERLY CONSTRUCTED, SUPPLIED, & CLEANED - Comments: OBSERVED DOOR TO FACILITY BATHROOM TO NOT BE SELF CLOSING. INSTRUCTED MANAGER TO PROVDE SELF CLOSING BATHROOM DOOR.'],
#  'violations_per_entry': {'min': 1,
#   'max': 28,
#   'avg': 7.555,
#   'distribution': {6: 98,
#    7: 96,
#    9: 93,
#    8: 83,
#    5: 83,
#    4: 78,
#    10: 78,
#    1: 74,
#    12: 58,
#    11: 53,
#    3: 52,
#    2: 44,
#    13: 27,
#    14: 22,
#    15: 21,
#    16: 14,
#    17: 10,
#    19: 8,
#    18: 3,
#    22: 2,
#    28: 1,
#    23: 1,
#    21: 1}}}

# %%
verify_violations_structure(updated_food_dataset)
# Out:
# Violations Structure Verification Results:
# {'total_checked': 207585, 'valid_entries': 207585, 'invalid_entries': 0, 'validity_percentage': 100.0, 'sample_invalid': []}
# {'total_checked': 207585,
#  'valid_entries': 207585,
#  'invalid_entries': 0,
#  'validity_percentage': 100.0,
#  'sample_invalid': []}

# %%
violations_df = parse_violations(updated_food_dataset) # parse the violations, output a separate dataframe. read the docstring for more details
profile_violations_normalized(violations_df)
# Out:
# /Users/giangson/coding/-DATA-PREPARATION-FOR-FOOD-INSPECTION/data_preparation.py:789: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='count', y='code_category', data=code_category_counts, palette='viridis')

# %%
result = association_rule_mining(
    updated_food_dataset,
    categorical_columns=['facility_type', 'risk', 'results', 'inspection_type'],
    violation_column='violations'
)

# %%
print(result)
# Out:
# {'violations': ['Violation_34 => Violation_33, Violation_35 (support: 0.102, confidence: 0.416, lift: 3.161)', 'Violation_33, Violation_35 => Violation_34 (support: 0.102, confidence: 0.779, lift: 3.161)', 'Violation_33 => Violation_34, Violation_35 (support: 0.102, confidence: 0.448, lift: 3.058)', 'Violation_34, Violation_35 => Violation_33 (support: 0.102, confidence: 0.700, lift: 3.058)', 'Violation_34, Violation_33 => Violation_35 (support: 0.102, confidence: 0.673, lift: 2.991)', 'Violation_35 => Violation_34, Violation_33 (support: 0.102, confidence: 0.455, lift: 2.991)', 'Violation_34 => Violation_33 (support: 0.152, confidence: 0.618, lift: 2.700)', 'Violation_33 => Violation_34 (support: 0.152, confidence: 0.665, lift: 2.700)', 'Violation_34 => Violation_35 (support: 0.146, confidence: 0.594, lift: 2.640)', 'Violation_35 => Violation_34 (support: 0.146, confidence: 0.651, lift: 2.640)'], 'categories': ['inspection_type_Canvass => results_Out of Business (support: 0.082, confidence: 0.159, lift: 1.892)', 'results_Out of Business => inspection_type_Canvass (support: 0.082, confidence: 0.984, lift: 1.892)', 'results_Pass, risk_High => facility_type_Restaurant, inspection_type_Canvass Re-Inspection (support: 0.052, confidence: 0.135, lift: 1.777)', 'facility_type_Restaurant, inspection_type_Canvass Re-Inspection => results_Pass, risk_High (support: 0.052, confidence: 0.693, lift: 1.777)', 'inspection_type_Canvass Re-Inspection => results_Pass, facility_type_Restaurant, risk_High (support: 0.052, confidence: 0.473, lift: 1.705)', 'results_Pass, facility_type_Restaurant, risk_High => inspection_type_Canvass Re-Inspection (support: 0.052, confidence: 0.189, lift: 1.705)', 'risk_High, inspection_type_Canvass Re-Inspection => results_Pass, facility_type_Restaurant (support: 0.052, confidence: 0.571, lift: 1.666)', 'results_Pass, facility_type_Restaurant => risk_High, inspection_type_Canvass Re-Inspection (support: 0.052, confidence: 0.153, lift: 1.666)', 'inspection_type_Canvass Re-Inspection => results_Pass, risk_High (support: 0.072, confidence: 0.647, lift: 1.661)', 'results_Pass, risk_High => inspection_type_Canvass Re-Inspection (support: 0.072, confidence: 0.184, lift: 1.661)'], 'facility_type_to_violations': ['facility_type_School => Violation_38 (support: 0.022, confidence: 0.351, lift: 1.461)', 'facility_type_Grocery Store => Violation_41 (support: 0.024, confidence: 0.197, lift: 1.446)', 'facility_type_Restaurant => Violation_58 (support: 0.057, confidence: 0.084, lift: 1.401)', 'facility_type_Grocery Store => Violation_34, Violation_35 (support: 0.024, confidence: 0.193, lift: 1.317)', 'facility_type_Restaurant => Violation_43 (support: 0.035, confidence: 0.052, lift: 1.312)', 'facility_type_Restaurant => Violation_30 (support: 0.048, confidence: 0.071, lift: 1.241)', 'facility_type_Grocery Store => Violation_34 (support: 0.037, confidence: 0.303, lift: 1.229)', 'facility_type_Restaurant => Violation_16 (support: 0.034, confidence: 0.051, lift: 1.214)', 'facility_type_Grocery Store => Violation_34, Violation_33 (support: 0.022, confidence: 0.183, lift: 1.202)', 'facility_type_Restaurant => Violation_57 (support: 0.036, confidence: 0.054, lift: 1.191)'], 'risk_to_violations': ['risk_High => Violation_58 (support: 0.059, confidence: 0.080, lift: 1.328)', 'risk_High => Violation_30 (support: 0.050, confidence: 0.068, lift: 1.185)', 'risk_High => Violation_47 (support: 0.072, confidence: 0.098, lift: 1.150)', 'risk_High => Violation_56 (support: 0.053, confidence: 0.071, lift: 1.148)', 'risk_High => Violation_56, Violation_55 (support: 0.038, confidence: 0.051, lift: 1.142)', 'risk_High => Violation_47, Violation_55 (support: 0.050, confidence: 0.067, lift: 1.138)', 'risk_High => Violation_49 (support: 0.066, confidence: 0.090, lift: 1.114)', 'risk_High => Violation_55, Violation_51 (support: 0.040, confidence: 0.055, lift: 1.108)', 'risk_High => Violation_51 (support: 0.062, confidence: 0.084, lift: 1.106)', 'risk_Hig ...

# %% [markdown]
# # Normalizing and storage

# %%
##### INGESTING TO SQL DATABASE #####
violations_df = parse_violations(updated_food_dataset) # parse the violations, output a separate dataframe. read the docstring for more details
facility_df, inspection_df = create_normalized_tables(updated_food_dataset) # Create the normalized tables

# Save tables to SQLite database
df_to_sqlite(violations_df, 'food_inspections.db', 'violations', if_exists='replace', index=False)
df_to_sqlite(facility_df, 'food_inspections.db', 'facility', if_exists='replace', index=False)
df_to_sqlite(inspection_df, 'food_inspections.db', 'inspection', if_exists='replace', index=False)
# Out:
# Successfully saved DataFrame to food_inspections.db as table 'violations'
# Table contains 937586 rows and 4 columns
# Successfully saved DataFrame to food_inspections.db as table 'facility'
# Table contains 46275 rows and 12 columns
# Successfully saved DataFrame to food_inspections.db as table 'inspection'
# Table contains 287237 rows and 6 columns
# True

# %%
# example query to check the data in the database
query = """
SELECT v.violation_code, v.category, COUNT(*) as violation_count
FROM violations v
-- JOIN violations vc ON v.inspection_id = vc.inspection_id
GROUP BY v.violation_code
ORDER BY violation_count DESC
LIMIT 10
"""
# Run the query and display the result
query_to_df('food_inspections.db', query)
# Out:
#    violation_code                                           category  \
# 0              38  VENTILATION: ROOMS AND EQUIPMENT VENTED AS REQ...
# 1              34  FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD RE...
# 2              55  PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN
# 3              33  FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSILS C...
# 4              35  WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTRUCTE...
# 5              32  FOOD AND NON-FOOD CONTACT SURFACES PROPERLY DE...
# 6              41              WIPING CLOTHS: PROPERLY USED & STORED
# 7              36                   THERMOMETERS PROVIDED & ACCURATE
# 8              47  FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PR...
# 9               3  POTENTIALLY HAZARDOUS FOOD MEETS TEMPERATURE R...
#
#    violation_count
# 0            72461
# 1            71698
# 2            69851
# 3            66487
# 4            65561
# 5            55172
# 6            39238
# 7            34335
# 8            31591
# 9            26751
